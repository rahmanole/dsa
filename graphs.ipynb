# %%
import numpy as np

# %%
num_nodes = 5
edges = [(0, 1),(0, 4),(1, 2),(1, 3),(1, 4),(2, 3),(3, 4)]
num_nodes, len(edges)
# Out:
# (5, 7)

# %%
class Graph:
  def __init__(self) -> None:
      pass

# %%
# !ls
# Out:
# sample_data
